# %%
# !pip install numpy pandas scikit-learn opencv-python pydicom pyradiomics
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting pyradiomics
#   Downloading pyradiomics-3.1.0.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 33.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Discarding https://files.pythonhosted.org/packages/03/c1/20fc2c50ab1e3304da36d866042a1905a2b05a1431ece35448ab6b4578f2/pyradiomics-3.1.0.tar.gz (from https://pypi.org/simple/pyradiomics/): Requested pyradiomics from https://files.pythonhosted.org/packages/03/c1/20fc2c50ab1e3304da36d866042a1905a2b05a1431ece35448ab6b4578f2/pyradiomics-3.1.0.tar.gz has inconsistent version: expected '3.1.0', but metadata has '3.0.1a1'
#   Downloading pyradiomics-3.0.1.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Collecting SimpleITK>=0.9.1 (from pyradiomics)
#   Downloading simpleitk-2.5.2-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pyradiomics) (1.8.0)
# Collecting pykwalify>=1.6.0 (from pyradiomics)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from pyradiomics) (1.17.0)
# Collecting docopt>=0.6.2 (from pykwalify>=1.6.0->pyradiomics)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml>=0.16.0 (from pykwalify>=1.6.0->pyradiomics)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16.0->pykwalify>=1.6.0->pyradiomics)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.8 MB/s eta 0:00:00
# Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Downloading simpleitk-2.5.2-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 11.1 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 11.0 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 43.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyradiomics, docopt
#   Building wheel for pyradiomics (setup.py) ... done
#   Created wheel for pyradiomics: filename=pyradiomics-3.0.1-cp311-cp311-linux_x86_64.whl size=170971 sha256=399c3dc6c22c3cf99197c2b72e754b24581c6fc796028a86d9afd607c21aebdd
#   Stored in directory: /root/.cache/pip/wheels/57/fb/95/931a5364368a3d8eaf9eee0daaf186e64b75fea7c1c97949fb
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=5f412c2c29da4127047d9b77ac7a391a13d66bb22d452b5f49cd671613811008
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built pyradiomics docopt
# Installing collected packages: SimpleITK, docopt, ruamel.yaml.clib, pydicom, ruamel.yaml, pykwalify, pyradiomics
# Successfully installed SimpleITK-2.5.2 docopt-0.6.2 pydicom-3.0.1 pykwalify-1.8.0 pyradiomics-3.0.1 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12

# %%
import numpy as np
import pandas as pd
import cv2
import os
import pydicom
from radiomics import featureextractor
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
from google.colab import files
files.upload()

# !pip install kaggle

# Create the kaggle directory and set permissions
# !mkdir -p ~/.kaggle
# !echo '{"username":"-","key":"-"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# Download the dataset
# !kaggle datasets download -d aryashah2k/breast-ultrasound-images-dataset

# Unzip it to a folder
# !unzip breast-ultrasound-images-dataset.zip -d /content/breast_ultrasound_images
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.6.15)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kagg
_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (244).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (244)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (245).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (245)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (246).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (246)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (247).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (247)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (248).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (248)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (249).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (249)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (25).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (25)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (25)_mask_1.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (250).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (250)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (251).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (251)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (252).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (252)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (253).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (253)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (254).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (254)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (255).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (255)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (256).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (256)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (257).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (257)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (258).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (258)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (259).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (259)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (26).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (26)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (260).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (260)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (261).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (261)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (262).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (262)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (263).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (263)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (264).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (264)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (265).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (265)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (266).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (266)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (267).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (267)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (268).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (268)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (269).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (269)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (27).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (27)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (270).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (270)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (271).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (271)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (272).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (272)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (273).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (273)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (274).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (274)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (275).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (275)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (276).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (276)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (277).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (277)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (278).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (278)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (279).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (279)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (28).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (28)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (280).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (280)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (281).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (281)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (282).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (282)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (283).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (283)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (284).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (284)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (285).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (285)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (286).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (286)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (287).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (287)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (288).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (288)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (289).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (289)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (29).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (29)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (290).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (290)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (291).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (291)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (292).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (292)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (293).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (293)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (294).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (294)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (295).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (295)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (296).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (296)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (297).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (297)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (298).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (298)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (299).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (299)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (3).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (3)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (30).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (30)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (300).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (300)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (301).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (301)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (302).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (302)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (303).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (303)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (304).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (304)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (305).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (305)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (306).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (306)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (307).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (307)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (308).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (308)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (309).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (309)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (31).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (31)_mask.png
# ...
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (23)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (24).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (24)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (25).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (25)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (26).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (26)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (27).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (27)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (28).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (28)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (29).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (29)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (3).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (3)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (30).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (30)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (31).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (31)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (32).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (32)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (33).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (33)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (34).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (34)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (35).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (35)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (36).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (36)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (37).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (37)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (38).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (38)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (39).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (39)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (4).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (4)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (40).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (40)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (41).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (41)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (42).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (42)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (43).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (43)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (44).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (44)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (45).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (45)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (46).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (46)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (47).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (47)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (48).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (48)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (49).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (49)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (5).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (5)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (50).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (50)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (51).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (51)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (52).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (52)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (53).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (53)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (54).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (54)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (55).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (55)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (56).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (56)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (57).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (57)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (58).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (58)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (59).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (59)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (6).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (6)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (60).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (60)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (61).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (61)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (62).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (62)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (63).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (63)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (64).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (64)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (65).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (65)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (66).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (66)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (67).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (67)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (68).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (68)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (69).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (69)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (7).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (7)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (70).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (70)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (71).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (71)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (72).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (72)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (73).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (73)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (74).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (74)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (75).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (75)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (76).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (76)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (77).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (77)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (78).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (78)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (79).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (79)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (8).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (8)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (80).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (80)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (81).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (81)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (82).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (82)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (83).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (83)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (84).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (84)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (85).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (85)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (86).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (86)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (87).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (87)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (88).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (88)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (89).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (89)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (9).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (9)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (90).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (90)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (91).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (91)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (92).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (92)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (93).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (93)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (94).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (94)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (95).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (95)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (96).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (96)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (97).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (97)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (98).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (98)_mask.png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (99).png
#   inflating: /content/breast_ultrasound_images/Dataset_BUSI_with_GT/normal/normal (99)_mask.png

# %%
import os

dataset_path = "/content/breast_ultrasound_images/Dataset_BUSI_with_GT"
categories = ["benign", "malignant", "normal"]

for category in categories:
    folder_path = os.path.join(dataset_path, category)
    if os.path.exists(folder_path):
        print(f"Found {len(os.listdir(folder_path))} images in '{category}' category.")
# Out:
# Found 891 images in 'benign' category.
# Found 421 images in 'malignant' category.
# Found 266 images in 'normal' category.

# %%
import cv2
import matplotlib.pyplot as plt

def show_sample_images(category):
    folder = os.path.join(dataset_path, category)
    images = os.listdir(folder)[:5]  # Show first 5 images

    plt.figure(figsize=(10,5))
    for i, img_name in enumerate(images):
        img_path = os.path.join(folder, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        plt.subplot(1, 5, i+1)
        plt.imshow(img, cmap="gray")
        plt.axis("off")
        plt.title(category)
    plt.show()

# Show sample images from each category
for cat in categories:
    show_sample_images(cat)

# %%
import shutil

# Create a new directory structure
data_dir = "/content/dataset_radiomics"
os.makedirs(data_dir, exist_ok=True)

for category in categories:
    src_folder = os.path.join(dataset_path, category)
    dest_folder = os.path.join(data_dir, category)
    os.makedirs(dest_folder, exist_ok=True)

    for file_name in os.listdir(src_folder):
        src_path = os.path.join(src_folder, file_name)
        dest_path = os.path.join(dest_folder, file_name)
        shutil.copy(src_path, dest_path)

print("Dataset is now ready for radiomics feature extraction.")
# Out:
# Dataset is now ready for radiomics feature extraction.

# %%
import os
import glob

dataset_path = "/content/breast_ultrasound_images/Dataset_BUSI_with_GT"
categories = ["benign", "malignant", "normal"]

image_paths = []
mask_paths = []

for category in categories:
    folder_path = os.path.join(dataset_path, category)

    if os.path.exists(folder_path):
        images = sorted(glob.glob(os.path.join(folder_path, "*.png")))  # Load all PNG files
        for img_path in images:
            if "_mask" not in img_path:  # Ignore mask files
                mask_path = img_path.replace(".png", "_mask.png")  # Find corresponding mask
                if os.path.exists(mask_path):  # Ensure mask exists
                    image_paths.append(img_path)
                    mask_paths.append(mask_path)

print(f"Total images: {len(image_paths)}, Total masks: {len(mask_paths)}")
# Out:
# Total images: 780, Total masks: 780

# %%
from sklearn.model_selection import train_test_split

train_images, val_images, train_masks, val_masks = train_test_split(
    image_paths, mask_paths, test_size=0.2, random_state=42
)

print(f"Training set: {len(train_images)} images, Validation set: {len(val_images)} images")
# Out:
# Training set: 624 images, Validation set: 156 images

# %%
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.Resize((256, 256)),  # Resize images & masks
    transforms.ToTensor(),  # Convert to tensor
])

# %%
from torch.utils.data import Dataset
from PIL import Image

class BreastTumorDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("RGB")
        mask = Image.open(self.mask_paths[idx]).convert("L")  # Convert to grayscale

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# %%
from torch.utils.data import DataLoader

train_dataset = BreastTumorDataset(train_images, train_masks, transform=transform)
val_dataset = BreastTumorDataset(val_images, val_masks, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %%
import torch
import torchvision.models.segmentation as models

# Load DeepLabV3+ with ResNet-101 backbone (pretrained on COCO)
model = models.deeplabv3_resnet101(pretrained=True)

# Modify the final classifier to match our dataset (1 class + background = 2 output channels)
model.classifier[4] = torch.nn.Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

print("Model Loaded Successfully")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:01<00:00, 178MB/s]
# Model Loaded Successfully

# %%
import torch.optim as optim

# Define loss function
criterion = torch.nn.CrossEntropyLoss()

# Define optimizer
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    model.train()

    for epoch in range(num_epochs):
        running_loss = 0.0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)['out']  # Get model predictions

            # Convert masks to LongTensor (required for CrossEntropyLoss)
            masks = masks.squeeze(1).long()

            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

    print("Training Complete")

# %%
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)
# Out:
# Epoch [1/10], Loss: 0.3643
# Epoch [2/10], Loss: 0.1745
# Epoch [3/10], Loss: 0.1125
# Epoch [4/10], Loss: 0.0821
# Epoch [5/10], Loss: 0.0675
# Epoch [6/10], Loss: 0.0729
# Epoch [7/10], Loss: 0.0650
# Epoch [8/10], Loss: 0.0543
# Epoch [9/10], Loss: 0.0425
# Epoch [10/10], Loss: 0.0344
# Training Complete

# %%
torch.save(model.state_dict(), "deeplabv3_breast_ultrasound.pth")
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
model.eval()  # Set model to evaluation mode
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
import torch.nn.functional as F

def compute_iou(pred_mask, true_mask):
    intersection = torch.logical_and(pred_mask, true_mask).sum().item()
    union = torch.logical_or(pred_mask, true_mask).sum().item()
    return intersection / union if union != 0 else 0

def evaluate_model(model, val_loader):
    model.eval()  # Set to eval mode
    iou_scores = []

    with torch.no_grad():
        for images, masks in val_loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)['out']
            predicted_masks = torch.argmax(outputs, dim=1)  # Get class with max probability

            for i in range(len(images)):
                iou = compute_iou(predicted_masks[i], masks[i])
                iou_scores.append(iou)

    avg_iou = sum(iou_scores) / len(iou_scores)
    print(f"Average IoU Score: {avg_iou:.4f}")

# Run evaluation
evaluate_model(model, val_loader)
# Out:
# Average IoU Score: 0.5280

# %%
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Load a test image
test_image_path = "/content/breast_ultrasound_images/Dataset_BUSI_with_GT/benign/benign (1).png"
image = Image.open(test_image_path).convert("RGB")

# Apply same transformations as training
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])
image_tensor = transform(image).unsqueeze(0).to(device)  # Add batch dimension

# Perform inference
model.eval()
with torch.no_grad():
    output = model(image_tensor)['out']

# Convert prediction to mask
pred_mask = torch.argmax(output, dim=1).squeeze(0).cpu().numpy()

# Display the result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(pred_mask, cmap="gray")
plt.title("Predicted Segmentation Mask")
plt.show()
